# %% [markdown]
# <center> <h1> Taller Python </h1>
#
# ![image](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTncB2fp8FCRjubfKXk8Hvl_NA8ycwu2BmHwQ&usqp=CAU)
#
# </center>
#
#
#
#
# Expositor: Katherine Morales
#
# - Linkedin [in/katherine-morales-7194a3108/](https://www.linkedin.com/in/katherine-morales-7194a3108/)

# %% [markdown]
# # Pandas

# %% [markdown]
# datos sobre las carreras universitarias extraídos de la Muestra de Microdatos de Uso Público de la Encuesta sobre la Comunidad Estadounidense 2010-2012. Sirvió de base para la Guía económica para elegir una carrera universitaria que aparece en el sitio web [FiveThirtyEight](https://fivethirtyeight.com/).

# %%
import pandas as pd

# %%
download_url = (
    "https://raw.githubusercontent.com/fivethirtyeight/"
    "data/master/college-majors/recent-grads.csv"
)

df = pd.read_csv(download_url)

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Rank                  173 non-null    int64
#  1   Major_code            173 non-null    int64
#  2   Major                 173 non-null    object
#  3   Total                 172 non-null    float64
#  4   Men                   172 non-null    float64
#  5   Women                 172 non-null    float64
#  6   Major_category        173 non-null    object
#  7   ShareWomen            172 non-null    float64
#  8   Sample_size           173 non-null    int64
#  9   Employed              173 non-null    int64
#  10  Full_time             173 non-null    int64
#  11  Part_time             173 non-null    int64
#  12  Full_time_year_round  173 non-null    int64
#  13  Unemployed            173 non-null    int64
#  14  Unemployment_rate     173 non-null    float64
# ...

# %%
df.tail(10)
# Out:
#      Rank  Major_code  ... Non_college_jobs  Low_wage_jobs
# 163   164        6102  ...             9404           5125
# 164   165        2307  ...             7705           2868
# 165   166        2603  ...             3703           1115
# 166   167        6001  ...            25313          11068
# 167   168        3302  ...             8100           3466
# 168   169        3609  ...             2947            743
# 169   170        5201  ...              615             82
# 170   171        5202  ...              870            622
# 171   172        5203  ...             1245            308
# 172   173        3501  ...              338            192
#
# [10 rows x 21 columns]

# %%
df.describe()
# Out:
#              Rank   Major_code  ...  Non_college_jobs  Low_wage_jobs
# count  173.000000   173.000000  ...        173.000000     173.000000
# mean    87.000000  3879.815029  ...      13284.497110    3859.017341
# std     50.084928  1687.753140  ...      23789.655363    6944.998579
# min      1.000000  1100.000000  ...          0.000000       0.000000
# 25%     44.000000  2403.000000  ...       1591.000000     340.000000
# 50%     87.000000  3608.000000  ...       4595.000000    1231.000000
# 75%    130.000000  5503.000000  ...      11783.000000    3466.000000
# max    173.000000  6403.000000  ...     148395.000000   48207.000000
#
# [8 rows x 19 columns]

# %% [markdown]
# - "Median" es la mediana de los ingresos de los trabajadores a tiempo completo durante todo el año.
# - "P25th" es el percentil 25 de los ingresos.
# - "P75th" es el percentil 75 de los ingresos.
# - "Rank" es el rango de la especialidad según la mediana de los ingresos.

# %% [markdown]
# .plot()
#
# - eje x: el rango de cada institución
# - eje y: P25th  y P75th

# %%
df.plot(x="Rank", y=["P25th", "P75th"])

# %%
import matplotlib.pyplot as plt
df.plot(x="Rank", y=["P25th", "P75th"])
plt.show()

# %% [markdown]
# Comentarios:
#
# -
#
# -
#
# -

# %% [markdown]
# Tarea:
#
# Añadir al eje y la variable 'Median'

# %%
## Código aquí


df.plot(x="Rank", y=["P25th", "P75th", 'Median'])
plt.show()

# %% [markdown]
# **.plot()** tiene varios parámetros
#
# *   area
# *   bar
# * barh
# * box
# * hexbin
# * hist
# * density
# * line
# * pie
# * scatter

# %% [markdown]
# Existe algún valor por default?

# %%
df["Median"].plot(kind="hist")
plt.show()

# %%
df["Median"].plot(kind="hist", bins = 20)

# %%
df["Median"].plot(kind="density")

# %%
df["Median"].plot(kind="density", color = 'red')

# %%
df["Median"].plot(kind="density", color = 'red', fontsize=11)

# %%
df["Median"].plot(kind="density", color = 'blue', fontsize=9, title='Mediana-densidad')

# %% [markdown]
# Tarea:
#
# Realizar el histograma de la variable Median solo para la categoria (Major_category) igual a ingenieria

# %%
## HERE
df[df["Major_category"] == "Engineering"]["Median"].plot(kind="hist")

# %% [markdown]
# ##

# %%
df.sort_values(by="Median", ascending=False).head() #expression
# Out:
#    Rank  Major_code  ... Non_college_jobs  Low_wage_jobs
# 0     1        2419  ...              364            193
# 1     2        2416  ...              257             50
# 2     3        2415  ...              176              0
# 3     4        2417  ...              102              0
# 4     5        2405  ...             4440            972
#
# [5 rows x 21 columns]

# %%
# Top 5 de las universidades mas lucrativas
top = df.sort_values(by="Median", ascending=False).head()

# %%
top.plot(x="Major", y="Median", kind="bar", rot=5, fontsize=4)

# %% [markdown]
# Tarea:
#
# Cambiar de colores a las barras de que representa cada universidad

# %%
## HERE


from matplotlib.cm import get_cmap

col = [i for i in get_cmap('tab20').colors]
#print(col)
top.plot(x="Major", y="Median", kind="bar", rot=90, fontsize=10, color = col)
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765), (0.6823529411764706, 0.7803921568627451, 0.9098039215686274), (1.0, 0.4980392156862745, 0.054901960784313725), (1.0, 0.7333333333333333, 0.47058823529411764), (0.17254901960784313, 0.6274509803921569, 0.17254901960784313), (0.596078431372549, 0.8745098039215686, 0.5411764705882353), (0.8392156862745098, 0.15294117647058825, 0.1568627450980392), (1.0, 0.596078431372549, 0.5882352941176471), (0.5803921568627451, 0.403921568627451, 0.7411764705882353), (0.7725490196078432, 0.6901960784313725, 0.8352941176470589), (0.5490196078431373, 0.33725490196078434, 0.29411764705882354), (0.7686274509803922, 0.611764705882353, 0.5803921568627451), (0.8901960784313725, 0.4666666666666667, 0.7607843137254902), (0.9686274509803922, 0.7137254901960784, 0.8235294117647058), (0.4980392156862745, 0.4980392156862745, 0.4980392156862745), (0.7803921568627451, 0.7803921568627451, 0.7803921568627451), (0.7372549019607844, 0.7411764705882353, 0.13
# ...

# %% [markdown]
# Añadir al gráfico de barras las variables P25th y P75th

# %%
## HERE

# %% [markdown]
# ## Analizar correlaciones
#
# Gráfico de dispersión?

# %% [markdown]
# Tarea:
#
# Gracifo de 'correlación' entre 'Median' y 'Unemployment_rate'

# %%
## HERE

df.plot(x="Median", y="Unemployment_rate", kind="scatter")

plt.xlabel('eje x')
plt.ylabel('eje y')
plt.show()

# %% [markdown]
# Un rápido vistazo a esta figura muestra que no hay una correlación significativa entre los ingresos y la tasa de desempleo.

# %% [markdown]
# ## Datos categóricos

# %% [markdown]
# utilizaramos .groupby() para determinar la popularidad de cada una de las categorías del conjunto de datos de las carreras universitarias

# %%
df.groupby("Major_category")["Total"].sum().sort_values()
# Out:
# Major_category
# Interdisciplinary                        12296.0
# Agriculture & Natural Resources          75620.0
# Law & Public Policy                     179107.0
# Physical Sciences                       185479.0
# Industrial Arts & Consumer Services     229792.0
# Computers & Mathematics                 299008.0
# Arts                                    357130.0
# Communications & Journalism             392601.0
# Biology & Life Science                  453862.0
# Health                                  463230.0
# Psychology & Social Work                481007.0
# Social Science                          529966.0
# Engineering                             537583.0
# Education                               559129.0
# Humanities & Liberal Arts               713468.0
# Business                               1302376.0
# Name: Total, dtype: float64

# %%
cat_totals = df.groupby("Major_category")["Total"].sum().sort_values()

# %%
cat_totals.plot(kind="barh", fontsize=10)

# %% [markdown]
# Tarea:
#
# - Agregar colores
# - Aumentar el tamaño del gráfico
# - Agregar nombre de los ejes
# - Agregar el titulo

# %%
## HERE
figs = (12,7)

cat_totals.plot(kind="barh", fontsize=15, figsize=figs , color=col)

# %% [markdown]
# ### Graficos de pastel

# %%
cat_totals.plot(kind="pie",figsize=figs )

# %% [markdown]
# Tarea:
#
# - Hacer el grafico pastel de las categorias en la cual la suma de la variable Total sea superior a 300000
#
# - Hacer el grafico pastel de las categorias en la cual la suma de la variable Total sea inferiores a 200000

# %%
# HERE
cat_totals_2 = cat_totals[cat_totals > 300000]
#cat_totals_2 = cat_totals[cat_totals > 300_000]

cat_totals_2.plot(kind="pie",figsize=figs)

# %% [markdown]
# # Matplotlib

# %%
plt.figure(figsize=(4,4))

import matplotlib.pyplot as plt

plt.plot(df["Rank"], df["P75th"])
plt.show()

# %%
df.plot(x="Rank", y="P75th", figsize=(4,4))

# %% [markdown]
# Tarea:
# - Anadir mas variables al grafico
# - Anadir etiquetas a las variables para saber a que variable corresponde cada linea
# - Anadir las etiquetas de los ejes x y y
# - Anadir el titulo

# %%
## HERE



plt.figure(figsize=(5,5))

plt.plot(df["Rank"], df["P75th"], label= 'P75th')
plt.plot(df["Rank"], df["P25th"])
plt.plot(df["Rank"], df["Median"])

plt.xlabel('Rango')

plt.grid(False)

plt.legend()


plt.show()

# %% [markdown]
# ## Varios graficos a la vez

# %%
fig, axes = plt.subplots(2,2)
#df["Median"].plot(kind="density", color = 'red', fontsize=11)
axes[0, 0].plot(df['Median'])
#df.plot(x="Median", y="Unemployment_rate", kind="scatter")
axes[0, 1].scatter(df['Median'], df['Unemployment_rate'])
#df.plot(x="Rank", y="P75th")
axes[1, 0].plot(df['Rank'], df['P75th'])
#df.plot(x="Rank", y="P25th")
axes[1, 1].plot(df['Rank'], df['P25th'])

# %% [markdown]
# ## Extra

# %%
plt.plot(df["Rank"], df["P75th"])

plt.text(x=25, y=100000, s=r'$\lambda=1, r^2=0.8$')

plt.annotate('Una flechita', xy=(100, 60000), xytext=(120, 62000), arrowprops={'facecolor':'red', 'shrink':0.05})
plt.show()

# %%
#
